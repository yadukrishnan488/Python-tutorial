# %% [markdown]
# <a href="https://colab.research.google.com/github/yadukrishnan488/Python-tutorial/blob/main/python_home.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("                    _____________________")
print("                  /  \\  \\ \\ \\ \\ \\ \\ \\ \\ \\ \\")
print("                 /____\\  \\ \\ \\ \\ \\ \\ \\ \\ \\ \\")
print("                /      \\  \\ \\ \\ \\ \\ \\ \\ \\ \\ \\")
print("               /________\\__\\_\\_\\_\\_\\_\\_\\_\\_\\_\\")
print("              |          |\"This is My house\"  | ")
print("              |          |       _____        | ")
print("              |  _____   |      |__|__|       | ")
print("              |  |   |   |      |__|__|       | ")
print("              |  |   |   |                    | ")
print("              |__|___|___|____________________| ")
# Out:
#                     _____________________
#                   /  \  \ \ \ \ \ \ \ \ \ \
#                  /____\  \ \ \ \ \ \ \ \ \ \
#                 /      \  \ \ \ \ \ \ \ \ \ \
#                /________\__\_\_\_\_\_\_\_\_\_\
#               |          |"This is My house"  |
#               |          |       _____        |
#               |  _____   |      |__|__|       |
#               |  |   |   |      |__|__|       |
#               |  |   |   |                    |
#               |__|___|___|____________________|

# %%
print("        __________________")
print("       /                  \\")
print("      /____________________\\")
print("      |                    |")
print("      |   \"MY HOUSE\"       |")
print("      |                    |")
print("      |      ______        |")
print("      |     |      |       |")
print("      |     | DOOR |       |")
print("      |     |______|       |")
print("      |____________________|")
# Out:
#         __________________
#        /                  \
#       /____________________\
#       |                    |
#       |   "MY HOUSE"       |
#       |                    |
#       |      ______        |
#       |     |      |       |
#       |     | DOOR |       |
#       |     |______|       |
#       |____________________|
