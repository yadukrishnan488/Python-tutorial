# %% [markdown]
# <a href="https://colab.research.google.com/github/yadukrishnan488/Python-tutorial/blob/main/Part_1_%E2%80%94_if_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
# Out:
# Enter a number: 12
# Positive

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("Eligible to vote")
# Out:
# Enter your age: 18
# Eligible to vote

# %%
temperature = float(input("Enter temperature: "))

if temperature > 30:
    print("It is a hot day")
# Out:
# Enter temperature: 45
# It is a hot day

# %%
num = int(input("Enter a number: "))

if num > 50:
    print("Greater than 50")
# Out:
# Enter a number: 67
# Greater than 50

# %%
mark = int(input("Enter your mark: "))

if mark >= 40:
    print("Pass")
# Out:
# Enter your mark: 60
# Pass

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even Number")
# Out:
# Enter a number: 34
# Even Number

# %%
amount = float(input("Enter shopping amount: "))

if amount >= 500:
    print("Free Delivery")
# Out:
# Enter shopping amount: 600
# Free Delivery

# %%
password = input("Enter password: ")

if len(password) >= 8:
    print("Strong Password")
# Out:
# Enter password: yadu@#123
# Strong Password
