# %% [markdown]
# <a href="https://colab.research.google.com/github/yadukrishnan488/Python-tutorial/blob/main/Part_2_%E2%80%94_if_else_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks = int(input("Enter marks: "))

if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks: 80
# Pass

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number: 34
# Even

# %%
age = int(input("Enter age: "))

if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
# Enter age: 18
# Eligible to vote

# %%
num = int(input("Enter a number: "))

if num >= 0:
    print("Positive")
else:
    print("Negative")
# Out:
# Enter a number: 456
# Positive

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print("Greater number:", a)
else:
    print("Greater number:", b)
# Out:
# Enter first number: 23
# Enter second number: 45
# Greater number: 45

# %%
correct_password = "12345"

password = input("Enter password: ")

if password == correct_password:
    print("Login Successful")
else:
    print("Incorrect Password")
# Out:
# Enter password: 12345
# Login Successful

# %%
1age = int(input("Enter age: "))

if age >= 18:
    print("Adult Ticket")
else:
    print("Child Ticket")
# Out:
# Enter age: 35
# Adult Ticket

# %%
amount = float(input("Enter shopping amount: "))

if amount >= 1000:
    print("Discount Available")
else:
    print("No Discount")
# Out:
# Enter shopping amount: 3666
# Discount Available

# %%
attendance = float(input("Enter attendance percentage: "))

if attendance >= 75:
    print("Eligible for Exam")
else:
    print("Not Eligible")
# Out:
# Enter attendance percentage: 80.4
# Eligible for Exam

# %%
num = int(input("Enter a number: "))

if num % 5 == 0:
    print("Divisible by 5")
else:
    print("Not Divisible by 5")
# Out:
# Enter a number: 34
# Not Divisible by 5

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print("Largest:", a)
else:
    print("Largest:", b)
# Out:
# Enter first number: 34
# Enter second number: 67
# Largest: 67

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a < b:
    print("Smallest:", a)
else:
    print("Smallest:", b)
# Out:
# Enter first number: 34
# Enter second number: 56
# Smallest: 34

# %%
temperature = float(input("Enter temperature: "))

if temperature >= 35:
    print("Very Hot")
else:
    print("Normal Temperature")
# Out:
# Enter temperature: 36
# Very Hot

# %%
balance = float(input("Enter account balance: "))
withdrawal = float(input("Enter withdrawal amount: "))

if withdrawal <= balance:
    print("Withdrawal Successful")
else:
    print("Insufficient Balance")
# Out:
# Enter account balance: 500
# Enter withdrawal amount: 1000
# Insufficient Balance

# %%
amount = float(input("Enter shopping amount: "))

if amount >= 2000:
    print("20% Discount")
else:
    print("No Discount")
# Out:
# Enter shopping amount: 5000
# 20% Discount

# %%
units = int(input("Enter units consumed: "))

if units > 100:
    print("High Electricity Usage")
else:
    print("Normal Usage")
# Out:
# Enter units consumed: 2
# Normal Usage

# %%
marks = int(input("Enter marks: "))

if marks >= 50:
    print("Passed the Subject")
else:
    print("Failed the Subject")
# Out:
# Enter marks: 60
# Passed the Subject

# %%
salary = float(input("Enter salary: "))

if salary < 30000:
    print("Eligible for Bonus")
else:
    print("Not Eligible for Bonus")
# Out:
# Enter salary: 400000
# Not Eligible for Bonus

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a == b:
    print("Both numbers are equal")
else:
    print("Numbers are different")
# Out:
# Enter first number: 45
# Enter second number: 67
# Numbers are different

# %%
age = int(input("Enter age: "))

if age >= 60:
    print("Senior Citizen Discount")
else:
    print("Regular Fare")
# Out:
# Enter age: 45
# Regular Fare
